# %%
from hummingbot_api_client import HummingbotAPIClient

client = HummingbotAPIClient(base_url='http://localhost:8000')
await client.init()

# %%
await client.connectors.list_connectors()
# Out:
# ['bitmart_perpetual',
#  'injective_v2_perpetual',
#  'hyperliquid_perpetual',
#  'hyperliquid_perpetual_testnet',
#  'binance_perpetual',
#  'binance_perpetual_testnet',
#  'dydx_v4_perpetual',
#  'derive_perpetual',
#  'derive_perpetual_testnet',
#  'bitget_perpetual',
#  'gate_io_perpetual',
#  'bybit_perpetual',
#  'bybit_perpetual_testnet',
#  'kucoin_perpetual',
#  'okx_perpetual',
#  'okx',
#  'htx',
#  'hyperliquid',
#  'hyperliquid_testnet',
#  'bing_x',
#  'ascend_ex',
#  'dexalot',
#  'dexalot_testnet',
#  'cube',
#  'bitstamp',
#  'btc_markets',
#  'gate_io',
#  'mexc',
#  'ndax',
#  'ndax_testnet',
#  'derive',
#  'derive_testnet',
#  'bitrue',
#  'bybit',
#  'bybit_testnet',
#  'coinbase_advanced_trade',
#  'kucoin',
#  'kucoin_hft',
#  'injective_v2',
#  'kraken',
#  'vertex',
#  'vertex_testnet',
#  'xrpl',
#  'bitmart',
#  'binance',
#  'binance_us']

# %%
await client.connectors.get_trading_rules("binance")
# Out:
# {'ETH-BTC': {'min_order_size': 0.0001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 0.0001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'LTC-BTC': {'min_order_size': 0.001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 0.001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'BNB-BTC': {'min_order_size': 0.001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 0.001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'NEO-BTC': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'QTUM-ETH': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'GAS-BTC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'BNB-ETH': {'min_order_size': 0.001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 0.001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'BTC-USDT': {'min_order_size': 1e-05,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'ETH-USDT': {'min_order_size': 0.0001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.0001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'LRC-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'LRC-ETH': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'QTUM-BTC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'ZRX-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'KNC-BTC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'IOTA-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'IOTA-ETH': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'LINK-BTC': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'LINK-ETH': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'XVG-ETH': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'MTL-BTC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'ETC-ETH': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'ETC-BTC': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'ZEC-BTC': {'min_order_size': 0.001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 0.001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'ZEC-ETH': {'min_order_size': 0.001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 0.001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'DASH-BTC': {'min_order_size': 0.001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 0.001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'DASH-ETH': {'min_order_size': 0.001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 0.001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'REQ-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'TRX-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'TRX-ETH': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'POWR-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'POWR-ETH': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'XRP-BTC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'XRP-ETH': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'ENJ-BTC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'STORJ-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'BNB-USDT': {'min_order_size': 0.001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'KMD-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'BAT-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'NEO-USDT': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'LSK-BTC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'MANA-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'MANA-ETH': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'ADX-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'ADX-ETH': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'ADA-BTC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'ADA-ETH': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'XLM-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'XLM-ETH': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'LTC-ETH': {'min_order_size': 0.001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 0.001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'LTC-USDT': {'min_order_size': 0.001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'LTC-BNB': {'min_order_size': 0.001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 0.001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.01,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BNB',
#   'sell_order_collateral_token': 'BNB'},
#  'ICX-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'RLC-BTC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'RLC-ETH': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'PIVX-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'STEEM-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'STEEM-ETH': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'ZIL-ETH': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'ONT-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'QTUM-USDT': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'WAN-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'SYS-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'ADA-USDT': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'ADA-BNB': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.01,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BNB',
#   'sell_order_collateral_token': 'BNB'},
#  'XRP-USDT': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'BTC-TUSD': {'min_order_size': 1e-05,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'TUSD',
#   'sell_order_collateral_token': 'TUSD'},
#  'ETH-TUSD': {'min_order_size': 0.0001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.0001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'TUSD',
#   'sell_order_collateral_token': 'TUSD'},
#  'ZEN-BTC': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'THETA-BTC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'XRP-BNB': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.01,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BNB',
#   'sell_order_collateral_token': 'BNB'},
#  'TUSD-USDT': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'IOTA-USDT': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'XLM-USDT': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'IOTX-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'IOTX-ETH': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'DATA-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'ONT-USDT': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'TRX-BNB': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.01,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BNB',
#   'sell_order_collateral_token': 'BNB'},
#  'TRX-USDT': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'ETC-USDT': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'ETC-BNB': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.01,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BNB',
#   'sell_order_collateral_token': 'BNB'},
#  'ICX-USDT': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'SC-ETH': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'DENT-ETH': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'ARDR-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'HOT-ETH': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'VET-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'VET-ETH': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'ETH',
#   'sell_order_collateral_token': 'ETH'},
#  'VET-USDT': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'VET-BNB': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.01,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BNB',
#   'sell_order_collateral_token': 'BNB'},
#  'RVN-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'BNB-TUSD': {'min_order_size': 0.001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'TUSD',
#   'sell_order_collateral_token': 'TUSD'},
#  'XRP-TUSD': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'TUSD',
#   'sell_order_collateral_token': 'TUSD'},
#  'BNB-USDC': {'min_order_size': 0.001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'BTC-USDC': {'min_order_size': 1e-05,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 1e-05,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'ETH-USDC': {'min_order_size': 0.0001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.0001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'XRP-USDC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'XLM-USDC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'USDC-USDT': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'TRX-XRP': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 10.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'XRP',
#   'sell_order_collateral_token': 'XRP'},
#  'LINK-USDT': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'LINK-USDC': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'LTC-USDC': {'min_order_size': 0.001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'TRX-USDC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'ONG-BTC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'ONG-USDT': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'HOT-USDT': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'ZIL-USDT': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'ZRX-USDT': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'FET-BNB': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.01,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BNB',
#   'sell_order_collateral_token': 'BNB'},
#  'FET-BTC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'FET-USDT': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'BAT-USDT': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'ZEC-USDT': {'min_order_size': 0.001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'IOST-USDT': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'CELR-USDT': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 0.1,
# ...
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'TRY',
#   'sell_order_collateral_token': 'TRY'},
#  'RSR-TRY': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 10.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'TRY',
#   'sell_order_collateral_token': 'TRY'},
#  'BB-BTC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'BB-USDT': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'BB-BNB': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-07,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.01,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BNB',
#   'sell_order_collateral_token': 'BNB'},
#  'BB-FDUSD': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'FDUSD',
#   'sell_order_collateral_token': 'FDUSD'},
#  'BB-TRY': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 10.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'TRY',
#   'sell_order_collateral_token': 'TRY'},
#  'PEOPLE-TRY': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 10.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'TRY',
#   'sell_order_collateral_token': 'TRY'},
#  'TRB-USDC': {'min_order_size': 0.001,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.001,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'NOT-USDT': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'NOT-FDUSD': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'FDUSD',
#   'sell_order_collateral_token': 'FDUSD'},
#  'NOT-TRY': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 10.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'TRY',
#   'sell_order_collateral_token': 'TRY'},
#  'ARKM-USDC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'AR-USDC': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'BB-USDC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'CRV-USDC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'PEOPLE-USDC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 1.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'AR-FDUSD': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'FDUSD',
#   'sell_order_collateral_token': 'FDUSD'},
#  'PEPE-EUR': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 1.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'REZ-USDC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'USDC-TRY': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 10.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'TRY',
#   'sell_order_collateral_token': 'TRY'},
#  'BTC-MXN': {'min_order_size': 1e-06,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1.0,
#   'min_base_amount_increment': 1e-06,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 150.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'MXN',
#   'sell_order_collateral_token': 'MXN'},
#  'XRP-MXN': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 150.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'MXN',
#   'sell_order_collateral_token': 'MXN'},
#  'ENS-USDC': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'LDO-USDC': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'NOT-USDC': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'NEAR-BRL': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 10.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BRL',
#   'sell_order_collateral_token': 'BRL'},
#  'HIGH-TRY': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 10.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'TRY',
#   'sell_order_collateral_token': 'TRY'},
#  'PEOPLE-FDUSD': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-05,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 1.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'FDUSD',
#   'sell_order_collateral_token': 'FDUSD'},
#  'TNSR-USDC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.0001,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDC',
#   'sell_order_collateral_token': 'USDC'},
#  'USDT-COP': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1.0,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 4000.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'COP',
#   'sell_order_collateral_token': 'COP'},
#  'IO-BTC': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  'IO-USDT': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'USDT',
#   'sell_order_collateral_token': 'USDT'},
#  'IO-BNB': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-06,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.01,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BNB',
#   'sell_order_collateral_token': 'BNB'},
#  'IO-FDUSD': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 5.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'FDUSD',
#   'sell_order_collateral_token': 'FDUSD'},
#  'IO-TRY': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.01,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 10.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'TRY',
#   'sell_order_collateral_token': 'TRY'},
#  'TRU-TRY': {'min_order_size': 1.0,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 1.0,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 10.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'TRY',
#   'sell_order_collateral_token': 'TRY'},
#  'WIF-EUR': {'min_order_size': 0.01,
#   'max_order_size': 1e+56,
#   'min_price_increment': 0.001,
#   'min_base_amount_increment': 0.01,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 1.0,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'EUR',
#   'sell_order_collateral_token': 'EUR'},
#  'ZK-BTC': {'min_order_size': 0.1,
#   'max_order_size': 1e+56,
#   'min_price_increment': 1e-08,
#   'min_base_amount_increment': 0.1,
#   'min_quote_amount_increment': 1e-56,
#   'min_notional_size': 0.0001,
#   'min_order_value': 0.0,
#   'max_price_significant_digits': 1e+56,
#   'supports_limit_orders': True,
#   'supports_market_orders': True,
#   'buy_order_collateral_token': 'BTC',
#   'sell_order_collateral_token': 'BTC'},
#  ...}

# %%
await client.connectors.get_config_map("binance")
# Out:
# ['binance_api_key', 'binance_api_secret']

# %%
await client.connectors.get_supported_order_types("binance")
# Out:
# {'connector': 'binance',
#  'supported_order_types': ['LIMIT', 'LIMIT_MAKER', 'MARKET']}
