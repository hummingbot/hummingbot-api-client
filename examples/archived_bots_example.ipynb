# %%
from hummingbot_api_client import HummingbotAPIClient

client = HummingbotAPIClient(base_url='http://localhost:8000')
await client.init()

# %%
dbs = await client.archived_bots.list_databases()
print(dbs)
# Out:
# ['bots/archived/sol-tole-controller-v3/data/sol-tole-controller-v3-20250702-175513.sqlite', 'bots/archived/hummingbot-test_bot-2025.05.28_17.55/data/test_bot-2025.sqlite', 'bots/archived/hummingbot-test_bot-2025.05.28_17.55/data/v2_with_controllers.sqlite', 'bots/archived/sol-tole-controller-v4/data/sol-tole-controller-v4-20250702-181303.sqlite', 'bots/archived/test/data/test-20250703-010429.sqlite', 'bots/archived/hummingbot-test-2025.05.28_23.14/data/v2_with_controllers.sqlite', 'bots/archived/hummingbot-test-2025.05.28_23.14/data/test-2025.sqlite', 'bots/archived/hummingbot-test22-20250529-1305/data/v2_with_controllers.sqlite', 'bots/archived/hummingbot-test22-20250529-1305/data/test22-20250529-1305.sqlite', 'bots/archived/hummingbot-sol-grid-long-bot-2025.06.11_17.58/data/sol-grid-long-bot-20250611-175257.sqlite', 'bots/archived/hummingbot-sol-grid-long-bot-2025.06.11_17.58/data/v2_with_controllers.sqlite', 'bots/archived/sol-grid-test/data/sol-grid-test-20250701-194848.sqlite', 'bots/archived/hummingbot-hummingbot-sol-tole-v2/data/hummingbot-sol-tole-v2-20250701-192757.sqlite', 'bots/archived/sol-tole-controller/data/sol-tole-controller-20250702-161536.sqlite', 'bots/archived/hummingbot-sol-grid-v3/data/sol-grid-v3-20250620-192414.sqlite', 'bots/archived/hummingbot-sol-grid-v3/data/v2_with_controllers.sqlite', 'bots/archived/hummingbot-test2-2025.05.28_18.02/data/v2_with_controllers.sqlite', 'bots/archived/hummingbot-test2-2025.05.28_18.02/data/test2-2025.sqlite']

# %%
await client.archived_bots.get_database_status(dbs[1])
# Out:
# {'db_path': 'bots/archived/hummingbot-test_bot-2025.05.28_17.55/data/test_bot-2025.sqlite',
#  'status': {'db_name': 'test_bot-2025.sqlite',
#   'db_path': 'sqlite:///bots/archived/hummingbot-test_bot-2025.05.28_17.55/data/test_bot-2025.sqlite',
#   'trade_fill': 'Correct',
#   'orders': 'Correct',
#   'order_status': 'Correct',
#   'executors': 'Correct',
#   'controllers': 'Correct',
#   'positions': 'Error - No records matched',
#   'general_status': False},
#  'healthy': False}

# %%
await client.archived_bots.get_database_performance(dbs[1])
# Out:
# {'db_path': 'bots/archived/hummingbot-test_bot-2025.05.28_17.55/data/test_bot-2025.sqlite',
#  'summary': {'total_trades': 12,
#   'final_net_pnl_quote': 0.052349133266805715,
#   'final_realized_pnl_quote': 0.053666133266805714,
#   'final_unrealized_pnl_quote': 0.0,
#   'total_fees_quote': 0.033967,
#   'final_net_position': 0.0,
#   'trading_pairs': ['WLD-USDT'],
#   'markets': ['binance_perpetual']},
#  'performance_data': [{'timestamp': 1748447747000,
#    'price': 1.3184,
#    'amount': 4.0,
#    'trade_type': 'BUY',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3184,
#    'buy_volume': 4.0,
#    'sell_avg_price': 0.0,
#    'sell_volume': 0.0,
#    'net_position': 4.0,
#    'realized_trade_pnl_pct': -1.0,
#    'realized_trade_pnl_quote': -0.0,
#    'unrealized_trade_pnl_pct': 0.0,
#    'unrealized_trade_pnl_quote': 0.0,
#    'fees_quote': 0.001054,
#    'net_pnl_quote': -0.001054},
#   {'timestamp': 1748447747000,
#    'price': 1.3175,
#    'amount': 5.0,
#    'trade_type': 'BUY',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3179,
#    'buy_volume': 9.0,
#    'sell_avg_price': 0.0,
#    'sell_volume': 0.0,
#    'net_position': 9.0,
#    'realized_trade_pnl_pct': -1.0,
#    'realized_trade_pnl_quote': -0.0,
#    'unrealized_trade_pnl_pct': -0.00030351316488366184,
#    'unrealized_trade_pnl_quote': -0.0027316184839529566,
#    'fees_quote': 0.001317,
#    'net_pnl_quote': -0.004048618483952956},
#   {'timestamp': 1748447769000,
#    'price': 1.3156,
#    'amount': 5.0,
#    'trade_type': 'BUY',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3170785714285713,
#    'buy_volume': 14.0,
#    'sell_avg_price': 0.0,
#    'sell_volume': 0.0,
#    'net_position': 14.0,
#    'realized_trade_pnl_pct': -1.0,
#    'realized_trade_pnl_quote': -0.0,
#    'unrealized_trade_pnl_pct': -0.0011226144443056904,
#    'unrealized_trade_pnl_quote': -0.015716602220279666,
#    'fees_quote': 0.001315,
#    'net_pnl_quote': -0.017031602220279666},
#   {'timestamp': 1748447772000,
#    'price': 1.3153,
#    'amount': 5.0,
#    'trade_type': 'BUY',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3166105263157895,
#    'buy_volume': 19.0,
#    'sell_avg_price': 0.0,
#    'sell_volume': 0.0,
#    'net_position': 19.0,
#    'realized_trade_pnl_pct': -1.0,
#    'realized_trade_pnl_quote': -0.0,
#    'unrealized_trade_pnl_pct': -0.0009953788835766982,
#    'unrealized_trade_pnl_quote': -0.018912198787957267,
#    'fees_quote': 0.001315,
#    'net_pnl_quote': -0.020227198787957267},
#   {'timestamp': 1748447777000,
#    'price': 1.3149,
#    'amount': 5.0,
#    'trade_type': 'BUY',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3162541666666667,
#    'buy_volume': 24.0,
#    'sell_avg_price': 0.0,
#    'sell_volume': 0.0,
#    'net_position': 24.0,
#    'realized_trade_pnl_pct': -1.0,
#    'realized_trade_pnl_quote': -0.0,
#    'unrealized_trade_pnl_pct': -0.0010288033276248702,
#    'unrealized_trade_pnl_quote': -0.024691279862996886,
#    'fees_quote': 0.001314,
#    'net_pnl_quote': -0.026005279862996885},
#   {'timestamp': 1748447782000,
#    'price': 1.3147,
#    'amount': 5.0,
#    'trade_type': 'BUY',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3159862068965518,
#    'buy_volume': 29.0,
#    'sell_avg_price': 0.0,
#    'sell_volume': 0.0,
#    'net_position': 29.0,
#    'realized_trade_pnl_pct': -1.0,
#    'realized_trade_pnl_quote': -0.0,
#    'unrealized_trade_pnl_pct': -0.0009773711075475554,
#    'unrealized_trade_pnl_quote': -0.028343762118879106,
#    'fees_quote': 0.001314,
#    'net_pnl_quote': -0.029657762118879105},
#   {'timestamp': 1748447785000,
#    'price': 1.3144,
#    'amount': 5.0,
#    'trade_type': 'BUY',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3157529411764706,
#    'buy_volume': 34.0,
#    'sell_avg_price': 0.0,
#    'sell_volume': 0.0,
#    'net_position': 34.0,
#    'realized_trade_pnl_pct': -1.0,
#    'realized_trade_pnl_quote': -0.0,
#    'unrealized_trade_pnl_pct': -0.001028263843560809,
#    'unrealized_trade_pnl_quote': -0.03496097068106751,
#    'fees_quote': 0.001314,
#    'net_pnl_quote': -0.03627497068106751},
#   {'timestamp': 1748447786000,
#    'price': 1.3141,
#    'amount': 5.0,
#    'trade_type': 'BUY',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3155410256410256,
#    'buy_volume': 39.0,
#    'sell_avg_price': 0.0,
#    'sell_volume': 0.0,
#    'net_position': 39.0,
#    'realized_trade_pnl_pct': -1.0,
#    'realized_trade_pnl_quote': -0.0,
#    'unrealized_trade_pnl_pct': -0.0010953863185858305,
#    'unrealized_trade_pnl_quote': -0.04272006642484739,
#    'fees_quote': 0.001314,
#    'net_pnl_quote': -0.04403406642484739},
#   {'timestamp': 1748447832000,
#    'price': 1.3177,
#    'amount': 5.0,
#    'trade_type': 'SELL',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3155410256410256,
#    'buy_volume': 39.0,
#    'sell_avg_price': 1.3177,
#    'sell_volume': 5.0,
#    'net_position': 34.0,
#    'realized_trade_pnl_pct': 0.0016411303919028222,
#    'realized_trade_pnl_quote': 0.008205651959514112,
#    'unrealized_trade_pnl_pct': 0.0016411303919028222,
#    'unrealized_trade_pnl_quote': 0.05579843332469596,
#    'fees_quote': 0.001317,
#    'net_pnl_quote': 0.06268708528421008},
#   {'timestamp': 1748447907000,
#    'price': 1.3173,
#    'amount': 27.0,
#    'trade_type': 'SELL',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3155410256410256,
#    'buy_volume': 39.0,
#    'sell_avg_price': 1.3173625,
#    'sell_volume': 32.0,
#    'net_position': 7.0,
#    'realized_trade_pnl_pct': 0.001384581950294437,
#    'realized_trade_pnl_quote': 0.044306622409421986,
#    'unrealized_trade_pnl_pct': 0.001337072979626174,
#    'unrealized_trade_pnl_quote': 0.009359510857383218,
#    'fees_quote': 0.017783,
#    'net_pnl_quote': 0.03588313326680521},
#   {'timestamp': 1748447907000,
#    'price': 1.3173,
#    'amount': 5.0,
#    'trade_type': 'SELL',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3155410256410256,
#    'buy_volume': 39.0,
#    'sell_avg_price': 1.317354054054054,
#    'sell_volume': 37.0,
#    'net_position': 2.0,
#    'realized_trade_pnl_pct': 0.0013781618191230501,
#    'realized_trade_pnl_quote': 0.050991987307552854,
#    'unrealized_trade_pnl_pct': 0.001337072979626174,
#    'unrealized_trade_pnl_quote': 0.002674145959252348,
#    'fees_quote': 0.003293,
#    'net_pnl_quote': 0.0503731332668052},
#   {'timestamp': 1748447907000,
#    'price': 1.3173,
#    'amount': 2.0,
#    'trade_type': 'SELL',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3155410256410256,
#    'buy_volume': 39.0,
#    'sell_avg_price': 1.317351282051282,
#    'sell_volume': 39.0,
#    'net_position': 0.0,
#    'realized_trade_pnl_pct': 0.0013760546991488645,
#    'realized_trade_pnl_quote': 0.053666133266805714,
#    'unrealized_trade_pnl_pct': 0.0,
#    'unrealized_trade_pnl_quote': 0.0,
#    'fees_quote': 0.001317,
#    'net_pnl_quote': 0.052349133266805715}]}

# %%
await client.archived_bots.get_database_trades(dbs[1])
# Out:
# {'db_path': 'bots/archived/hummingbot-test_bot-2025.05.28_17.55/data/test_bot-2025.sqlite',
#  'trades': [{'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'timestamp': 1748447747000,
#    'order_id': 'x-nbQe1H39BWDUT6363435a9c31b0bb9',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 1.3184,
#    'amount': 4.0,
#    'leverage': 20,
#    'trade_fee': 0.0,
#    'trade_fee_in_quote': 0.001054,
#    'exchange_trade_id': '978104923',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.001054},
#   {'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'timestamp': 1748447747000,
#    'order_id': 'x-nbQe1H39BWDUT63634358b33020bb9',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 1.3175,
#    'amount': 5.0,
#    'leverage': 20,
#    'trade_fee': 0.0013169999999999998,
#    'trade_fee_in_quote': 0.001317,
#    'exchange_trade_id': '978105042',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.002371},
#   {'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'timestamp': 1748447769000,
#    'order_id': 'x-nbQe1H39BWDUT6363437096a740bb9',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 1.3156,
#    'amount': 5.0,
#    'leverage': 20,
#    'trade_fee': 0.0013150000000000002,
#    'trade_fee_in_quote': 0.001315,
#    'exchange_trade_id': '978105634',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.003686},
#   {'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'timestamp': 1748447772000,
#    'order_id': 'x-nbQe1H39BWDUT63634383b12650bb9',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 1.3153,
#    'amount': 5.0,
#    'leverage': 20,
#    'trade_fee': 0.0013150000000000002,
#    'trade_fee_in_quote': 0.001315,
#    'exchange_trade_id': '978105676',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.005001},
#   {'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'timestamp': 1748447777000,
#    'order_id': 'x-nbQe1H39BWDUT636343868f1a70bb9',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 1.3149,
#    'amount': 5.0,
#    'leverage': 20,
#    'trade_fee': 0.001314,
#    'trade_fee_in_quote': 0.001314,
#    'exchange_trade_id': '978105742',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.006315},
#   {'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'timestamp': 1748447782000,
#    'order_id': 'x-nbQe1H39BWDUT6363438b5623b0bb9',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 1.3147,
#    'amount': 5.0,
#    'leverage': 20,
#    'trade_fee': 0.001314,
#    'trade_fee_in_quote': 0.001314,
#    'exchange_trade_id': '978105822',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.007629},
#   {'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'timestamp': 1748447785000,
#    'order_id': 'x-nbQe1H39BWDUT636343901d1a60bb9',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 1.3144,
#    'amount': 5.0,
#    'leverage': 20,
#    'trade_fee': 0.0013139999999999992,
#    'trade_fee_in_quote': 0.001314,
#    'exchange_trade_id': '978105872',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.008943},
#   {'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'timestamp': 1748447786000,
#    'order_id': 'x-nbQe1H39BWDUT63634392faab50bb9',
#    'trade_type': 'BUY',
#    'order_type': 'LIMIT_MAKER',
#    'price': 1.3141,
#    'amount': 5.0,
#    'leverage': 20,
#    'trade_fee': 0.001314000000000001,
#    'trade_fee_in_quote': 0.001314,
#    'exchange_trade_id': '978105936',
#    'position': 'OPEN',
#    'cum_fees_in_quote': 0.010257},
#   {'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'timestamp': 1748447832000,
#    'order_id': 'x-nbQe1H39SWDUT6363436ead42d0bb9',
#    'trade_type': 'SELL',
#    'order_type': 'LIMIT_MAKER',
#    'price': 1.3177,
#    'amount': 5.0,
#    'leverage': 20,
#    'trade_fee': 0.0013170000000000005,
#    'trade_fee_in_quote': 0.001317,
#    'exchange_trade_id': '978106430',
#    'position': 'CLOSE',
#    'cum_fees_in_quote': 0.011574000000000001},
#   {'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'timestamp': 1748447907000,
#    'order_id': 'x-nbQe1H39SWDUT63634406afee90bb9',
#    'trade_type': 'SELL',
#    'order_type': 'MARKET',
#    'price': 1.3173,
#    'amount': 27.0,
#    'leverage': 20,
#    'trade_fee': 0.017783,
#    'trade_fee_in_quote': 0.017783,
#    'exchange_trade_id': '978106967',
#    'position': 'CLOSE',
#    'cum_fees_in_quote': 0.029357},
#   {'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'timestamp': 1748447907000,
#    'order_id': 'x-nbQe1H39SWDUT63634406afee90bb9',
#    'trade_type': 'SELL',
#    'order_type': 'MARKET',
#    'price': 1.3173,
#    'amount': 5.0,
#    'leverage': 20,
#    'trade_fee': 0.0032929999999999973,
#    'trade_fee_in_quote': 0.003293,
#    'exchange_trade_id': '978106968',
#    'position': 'CLOSE',
#    'cum_fees_in_quote': 0.03265},
#   {'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'timestamp': 1748447907000,
#    'order_id': 'x-nbQe1H39SWDUT63634406afee90bb9',
#    'trade_type': 'SELL',
#    'order_type': 'MARKET',
#    'price': 1.3173,
#    'amount': 2.0,
#    'leverage': 20,
#    'trade_fee': 0.0013170000000000057,
#    'trade_fee_in_quote': 0.001317,
#    'exchange_trade_id': '978106969',
#    'position': 'CLOSE',
#    'cum_fees_in_quote': 0.033967000000000004}],
#  'pagination': {'total': 12, 'limit': 100, 'offset': 0, 'has_more': False}}

# %%
await client.archived_bots.get_database_orders(dbs[1])
# Out:
# {'db_path': 'bots/archived/hummingbot-test_bot-2025.05.28_17.55/data/test_bot-2025.sqlite',
#  'orders': [{'id': 'x-nbQe1H39BWDUT63634358b33020bb9',
#    'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'creation_timestamp': 1748447724000,
#    'order_type': 'LIMIT_MAKER',
#    'amount': 5.0,
#    'leverage': 20,
#    'price': 1.3175,
#    'last_status': 'BuyOrderCompleted',
#    'last_update_timestamp': 1748447747559,
#    'exchange_order_id': '15443174267',
#    'position': 'OPEN'},
#   {'id': 'x-nbQe1H39BWDUT6363435a9c31b0bb9',
#    'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'creation_timestamp': 1748447726000,
#    'order_type': 'LIMIT_MAKER',
#    'amount': 4.0,
#    'leverage': 20,
#    'price': 1.3184,
#    'last_status': 'BuyOrderCompleted',
#    'last_update_timestamp': 1748447747555,
#    'exchange_order_id': '15443175069',
#    'position': 'OPEN'},
#   {'id': 'x-nbQe1H39BWDUT6363435c859320bb9',
#    'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'creation_timestamp': 1748447728000,
#    'order_type': 'LIMIT_MAKER',
#    'amount': 4.0,
#    'leverage': 20,
#    'price': 1.3117,
#    'last_status': 'OrderCancelled',
#    'last_update_timestamp': 1748447901795,
#    'exchange_order_id': '15443175628',
#    'position': 'OPEN'},
#   {'id': 'x-nbQe1H39BWDUT6363436ead1740bb9',
#    'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'creation_timestamp': 1748447747000,
#    'order_type': 'LIMIT_MAKER',
#    'amount': 5.0,
#    'leverage': 20,
#    'price': 1.3058,
#    'last_status': 'OrderCancelled',
#    'last_update_timestamp': 1748447901262,
#    'exchange_order_id': '15443184568',
#    'position': 'OPEN'},
#   {'id': 'x-nbQe1H39SWDUT6363436ead42d0bb9',
#    'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'creation_timestamp': 1748447747000,
#    'order_type': 'LIMIT_MAKER',
#    'amount': 5.0,
#    'leverage': 20,
#    'price': 1.3177,
#    'last_status': 'SellOrderCompleted',
#    'last_update_timestamp': 1748447832183,
#    'exchange_order_id': '15443185528',
#    'position': 'CLOSE'},
#   {'id': 'x-nbQe1H39SWDUT6363436ead6050bb9',
#    'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'creation_timestamp': 1748447747000,
#    'order_type': 'LIMIT_MAKER',
#    'amount': 4.0,
#    'leverage': 20,
#    'price': 1.3235,
#    'last_status': 'OrderCancelled',
#    'last_update_timestamp': 1748447901813,
#    'exchange_order_id': '15443185527',
#    'position': 'CLOSE'},
#   {'id': 'x-nbQe1H39BWDUT6363437096a740bb9',
#    'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'creation_timestamp': 1748447749000,
#    'order_type': 'LIMIT_MAKER',
#    'amount': 5.0,
#    'leverage': 20,
#    'price': 1.3156,
#    'last_status': 'BuyOrderCompleted',
#    'last_update_timestamp': 1748447769366,
#    'exchange_order_id': '15443186374',
#    'position': 'OPEN'},
#   {'id': 'x-nbQe1H39BWDUT63634383b12650bb9',
#    'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'creation_timestamp': 1748447769000,
#    'order_type': 'LIMIT_MAKER',
#    'amount': 5.0,
#    'leverage': 20,
#    'price': 1.3153,
#    'last_status': 'BuyOrderCompleted',
#    'last_update_timestamp': 1748447772198,
#    'exchange_order_id': '15443192502',
#    'position': 'OPEN'},
#   {'id': 'x-nbQe1H39BWDUT636343868f1a70bb9',
#    'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'creation_timestamp': 1748447772000,
#    'order_type': 'LIMIT_MAKER',
#    'amount': 5.0,
#    'leverage': 20,
#    'price': 1.3149,
#    'last_status': 'BuyOrderCompleted',
#    'last_update_timestamp': 1748447777422,
#    'exchange_order_id': '15443193989',
#    'position': 'OPEN'},
#   {'id': 'x-nbQe1H39BWDUT6363438b5623b0bb9',
#    'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'creation_timestamp': 1748447777000,
#    'order_type': 'LIMIT_MAKER',
#    'amount': 5.0,
#    'leverage': 20,
#    'price': 1.3147,
#    'last_status': 'BuyOrderCompleted',
#    'last_update_timestamp': 1748447782086,
#    'exchange_order_id': '15443195639',
#    'position': 'OPEN'},
#   {'id': 'x-nbQe1H39BWDUT636343901d1a60bb9',
#    'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'creation_timestamp': 1748447782000,
#    'order_type': 'LIMIT_MAKER',
#    'amount': 5.0,
#    'leverage': 20,
#    'price': 1.3144,
#    'last_status': 'BuyOrderCompleted',
#    'last_update_timestamp': 1748447785049,
#    'exchange_order_id': '15443196680',
#    'position': 'OPEN'},
#   {'id': 'x-nbQe1H39BWDUT63634392faab50bb9',
#    'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'creation_timestamp': 1748447785000,
#    'order_type': 'LIMIT_MAKER',
#    'amount': 5.0,
#    'leverage': 20,
#    'price': 1.3141,
#    'last_status': 'BuyOrderCompleted',
#    'last_update_timestamp': 1748447786598,
#    'exchange_order_id': '15443198065',
#    'position': 'OPEN'},
#   {'id': 'x-nbQe1H39BWDUT63634394e3cbb0bb9',
#    'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'creation_timestamp': 1748447787000,
#    'order_type': 'LIMIT_MAKER',
#    'amount': 5.0,
#    'leverage': 20,
#    'price': 1.3142,
#    'last_status': 'OrderCancelled',
#    'last_update_timestamp': 1748447901808,
#    'exchange_order_id': '15443199035',
#    'position': 'OPEN'},
#   {'id': 'x-nbQe1H39SWDUT636343a5218640bb9',
#    'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'creation_timestamp': 1748447804000,
#    'order_type': 'LIMIT_MAKER',
#    'amount': 5.0,
#    'leverage': 20,
#    'price': 1.3294,
#    'last_status': 'OrderCancelled',
#    'last_update_timestamp': 1748447901803,
#    'exchange_order_id': '15443205297',
#    'position': 'CLOSE'},
#   {'id': 'x-nbQe1H39SWDUT63634406afee90bb9',
#    'config_file_path': 'test_bot-2025.05.28_17.55.yml',
#    'strategy': 'v2_with_controllers',
#    'market': 'binance_perpetual',
#    'symbol': 'WLD-USDT',
#    'base_asset': 'WLD',
#    'quote_asset': 'USDT',
#    'creation_timestamp': 1748447907000,
#    'order_type': 'MARKET',
#    'amount': 34.0,
#    'leverage': 20,
#    'price': 0.0,
#    'last_status': 'SellOrderCompleted',
#    'last_update_timestamp': 1748447907502,
#    'exchange_order_id': '15443237280',
#    'position': 'CLOSE'}],
#  'pagination': {'total': 15, 'limit': 100, 'offset': 0, 'has_more': False}}

# %%
await client.archived_bots.get_database_executors(dbs[1])
# Out:
# {'db_path': 'bots/archived/hummingbot-test_bot-2025.05.28_17.55/data/test_bot-2025.sqlite',
#  'executors': [{'id': '6p4JGSUWtdLAwxYyppv26PE2knkVwZgQzKChBoKr33ny',
#    'timestamp': 1748447724.7717595,
#    'type': 'grid_executor',
#    'close_type': 5,
#    'close_timestamp': 1748447913,
#    'status': 4,
#    'config': '{"id": "6p4JGSUWtdLAwxYyppv26PE2knkVwZgQzKChBoKr33ny", "type": "grid_executor", "timestamp": 1748447724.7717595, "controller_id": "binary-rich_0.1", "connector_name": "binance_perpetual", "trading_pair": "WLD-USDT", "start_price": "1.3", "end_price": "1.47", "limit_price": "0.8644999999999999", "side": 1, "total_amount_quote": "200.0", "min_spread_between_orders": "0.0001", "min_order_amount_quote": "6.0", "max_open_orders": 3, "max_orders_per_batch": 1, "order_frequency": 2, "activation_bounds": "0.01", "safe_extra_spread": "0.0001", "triple_barrier_config": {"stop_loss": "0.1", "take_profit": "0.0001", "time_limit": null, "trailing_stop": null, "open_order_type": 3, "take_profit_order_type": 3, "stop_loss_order_type": 1, "time_limit_order_type": 1}, "leverage": 20, "level_id": null, "deduct_base_fees": false, "keep_position": false, "coerce_tp_to_step": false}',
#    'net_pnl_pct': 0.00026959987456516576,
#    'net_pnl_quote': 0.027683270000000003,
#    'cum_fees_quote': 0.04291673,
#    'filled_amount_quote': 102.6828,
#    'is_active': 0,
#    'is_trading': 0,
#    'custom_info': '{"levels_by_state": {}, "filled_orders": [{"client_order_id": "x-nbQe1H39BWDUT63634358b33020bb9", "exchange_order_id": "15443174267", "trading_pair": "WLD-USDT", "order_type": "LIMIT_MAKER", "trade_type": "BUY", "price": "1.3175000", "amount": "5", "executed_amount_base": "5", "executed_amount_quote": "6.5875", "last_state": "5", "leverage": "20", "position": "OPEN", "creation_timestamp": 1748447724.0, "last_update_timestamp": 1748447747.217, "order_fills": {"978105042": {"trade_id": "978105042", "client_order_id": "x-nbQe1H39BWDUT63634358b33020bb9", "exchange_order_id": "15443174267", "trading_pair": "WLD-USDT", "fill_timestamp": 1748447747.217, "fill_price": "1.3175", "fill_base_amount": "5", "fill_quote_amount": "6.5875", "fee": {"fee_type": "AddedToCost", "percent": "0", "percent_token": "USDT", "flat_fees": [{"token": "USDT", "amount": "0.0013175"}]}, "is_taker": true}}, "cumulative_fee_paid_base": 0.0009992415623814941, "cumulative_fee_paid_quote": 0.0013175}, {"client_order_id": "x-nbQe1H39SWDUT6363436ead42d0bb9", "exchange_order_id": "15443185528", "trading_pair": "WLD-USDT", "order_type": "LIMIT_MAKER", "trade_type": "SELL", "price": "1.3177000", "amount": "5", "executed_amount_base": "5", "executed_amount_quote": "6.5885", "last_state": "1", "leverage": "20", "position": "CLOSE", "creation_timestamp": 1748447747.0, "last_update_timestamp": 1748447832.118, "order_fills": {"978106430": {"trade_id": "978106430", "client_order_id": "x-nbQe1H39SWDUT6363436ead42d0bb9", "exchange_order_id": "15443185528", "trading_pair": "WLD-USDT", "fill_timestamp": 1748447832.118, "fill_price": "1.3177", "fill_base_amount": "5", "fill_quote_amount": "6.5885", "fee": {"fee_type": "DeductedFromReturns", "percent": "0", "percent_token": "USDT", "flat_fees": [{"token": "USDT", "amount": "0.0013177"}]}, "is_taker": true}}, "cumulative_fee_paid_base": 0.0009993932499051954, "cumulative_fee_paid_quote": 0.0013177}, {"client_order_id": "x-nbQe1H39BWDUT6363435a9c31b0bb9", "exchange_order_id": "15443175069", "trading_pair": "WLD-USDT", "order_type": "LIMIT_MAKER", "trade_type": "BUY", "price": "1.3184000", "amount": "4", "executed_amount_base": "4", "executed_amount_quote": "5.2736", "last_state": "5", "leverage": "20", "position": "OPEN", "creation_timestamp": 1748447726.0, "last_update_timestamp": 1748447747.217, "order_fills": {"978104923": {"trade_id": "978104923", "client_order_id": "x-nbQe1H39BWDUT6363435a9c31b0bb9", "exchange_order_id": "15443175069", "trading_pair": "WLD-USDT", "fill_timestamp": 1748447747.217, "fill_price": "1.3184", "fill_base_amount": "4", "fill_quote_amount": "5.2736", "fee": {"fee_type": "AddedToCost", "percent": "0", "percent_token": "USDT", "flat_fees": [{"token": "USDT", "amount": "0.00105472"}]}, "is_taker": true}}, "cumulative_fee_paid_base": 0.0007999393249905196, "cumulative_fee_paid_quote": 0.00105472}, {"client_order_id": "x-nbQe1H39BWDUT6363437096a740bb9", "exchange_order_id": "15443186374", "trading_pair": "WLD-USDT", "order_type": "LIMIT_MAKER", "trade_type": "BUY", "price": "1.3156000", "amount": "5", "executed_amount_base": "5", "executed_amount_quote": "6.5780", "last_state": "5", "leverage": "20", "position": "OPEN", "creation_timestamp": 1748447749.0, "last_update_timestamp": 1748447769.309, "order_fills": {"978105634": {"trade_id": "978105634", "client_order_id": "x-nbQe1H39BWDUT6363437096a740bb9", "exchange_order_id": "15443186374", "trading_pair": "WLD-USDT", "fill_timestamp": 1748447769.309, "fill_price": "1.3156", "fill_base_amount": "5", "fill_quote_amount": "6.5780", "fee": {"fee_type": "AddedToCost", "percent": "0", "percent_token": "USDT", "flat_fees": [{"token": "USDT", "amount": "0.0013156"}]}, "is_taker": true}}, "cumulative_fee_paid_base": 0.0009978005309063329, "cumulative_fee_paid_quote": 0.0013156}, {"client_order_id": "x-nbQe1H39BWDUT63634383b12650bb9", "exchange_order_id": "15443192502", "trading_pair": "WLD-USDT", "order_type": "LIMIT_MAKER", "trade_type": "BUY", " ...
#    'controller_id': 'binary-rich_0.1'}],
#  'total': 1}

# %%
await client.archived_bots.get_database_performance(dbs[1])
# Out:
# {'db_path': 'bots/archived/hummingbot-test_bot-2025.05.28_17.55/data/test_bot-2025.sqlite',
#  'summary': {'total_trades': 12,
#   'final_net_pnl_quote': 0.052349133266805715,
#   'final_realized_pnl_quote': 0.053666133266805714,
#   'final_unrealized_pnl_quote': 0.0,
#   'total_fees_quote': 0.033967,
#   'final_net_position': 0.0,
#   'trading_pairs': ['WLD-USDT'],
#   'markets': ['binance_perpetual']},
#  'performance_data': [{'timestamp': 1748447747000,
#    'price': 1.3184,
#    'amount': 4.0,
#    'trade_type': 'BUY',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3184,
#    'buy_volume': 4.0,
#    'sell_avg_price': 0.0,
#    'sell_volume': 0.0,
#    'net_position': 4.0,
#    'realized_trade_pnl_pct': -1.0,
#    'realized_trade_pnl_quote': -0.0,
#    'unrealized_trade_pnl_pct': 0.0,
#    'unrealized_trade_pnl_quote': 0.0,
#    'fees_quote': 0.001054,
#    'net_pnl_quote': -0.001054},
#   {'timestamp': 1748447747000,
#    'price': 1.3175,
#    'amount': 5.0,
#    'trade_type': 'BUY',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3179,
#    'buy_volume': 9.0,
#    'sell_avg_price': 0.0,
#    'sell_volume': 0.0,
#    'net_position': 9.0,
#    'realized_trade_pnl_pct': -1.0,
#    'realized_trade_pnl_quote': -0.0,
#    'unrealized_trade_pnl_pct': -0.00030351316488366184,
#    'unrealized_trade_pnl_quote': -0.0027316184839529566,
#    'fees_quote': 0.001317,
#    'net_pnl_quote': -0.004048618483952956},
#   {'timestamp': 1748447769000,
#    'price': 1.3156,
#    'amount': 5.0,
#    'trade_type': 'BUY',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3170785714285713,
#    'buy_volume': 14.0,
#    'sell_avg_price': 0.0,
#    'sell_volume': 0.0,
#    'net_position': 14.0,
#    'realized_trade_pnl_pct': -1.0,
#    'realized_trade_pnl_quote': -0.0,
#    'unrealized_trade_pnl_pct': -0.0011226144443056904,
#    'unrealized_trade_pnl_quote': -0.015716602220279666,
#    'fees_quote': 0.001315,
#    'net_pnl_quote': -0.017031602220279666},
#   {'timestamp': 1748447772000,
#    'price': 1.3153,
#    'amount': 5.0,
#    'trade_type': 'BUY',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3166105263157895,
#    'buy_volume': 19.0,
#    'sell_avg_price': 0.0,
#    'sell_volume': 0.0,
#    'net_position': 19.0,
#    'realized_trade_pnl_pct': -1.0,
#    'realized_trade_pnl_quote': -0.0,
#    'unrealized_trade_pnl_pct': -0.0009953788835766982,
#    'unrealized_trade_pnl_quote': -0.018912198787957267,
#    'fees_quote': 0.001315,
#    'net_pnl_quote': -0.020227198787957267},
#   {'timestamp': 1748447777000,
#    'price': 1.3149,
#    'amount': 5.0,
#    'trade_type': 'BUY',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3162541666666667,
#    'buy_volume': 24.0,
#    'sell_avg_price': 0.0,
#    'sell_volume': 0.0,
#    'net_position': 24.0,
#    'realized_trade_pnl_pct': -1.0,
#    'realized_trade_pnl_quote': -0.0,
#    'unrealized_trade_pnl_pct': -0.0010288033276248702,
#    'unrealized_trade_pnl_quote': -0.024691279862996886,
#    'fees_quote': 0.001314,
#    'net_pnl_quote': -0.026005279862996885},
#   {'timestamp': 1748447782000,
#    'price': 1.3147,
#    'amount': 5.0,
#    'trade_type': 'BUY',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3159862068965518,
#    'buy_volume': 29.0,
#    'sell_avg_price': 0.0,
#    'sell_volume': 0.0,
#    'net_position': 29.0,
#    'realized_trade_pnl_pct': -1.0,
#    'realized_trade_pnl_quote': -0.0,
#    'unrealized_trade_pnl_pct': -0.0009773711075475554,
#    'unrealized_trade_pnl_quote': -0.028343762118879106,
#    'fees_quote': 0.001314,
#    'net_pnl_quote': -0.029657762118879105},
#   {'timestamp': 1748447785000,
#    'price': 1.3144,
#    'amount': 5.0,
#    'trade_type': 'BUY',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3157529411764706,
#    'buy_volume': 34.0,
#    'sell_avg_price': 0.0,
#    'sell_volume': 0.0,
#    'net_position': 34.0,
#    'realized_trade_pnl_pct': -1.0,
#    'realized_trade_pnl_quote': -0.0,
#    'unrealized_trade_pnl_pct': -0.001028263843560809,
#    'unrealized_trade_pnl_quote': -0.03496097068106751,
#    'fees_quote': 0.001314,
#    'net_pnl_quote': -0.03627497068106751},
#   {'timestamp': 1748447786000,
#    'price': 1.3141,
#    'amount': 5.0,
#    'trade_type': 'BUY',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3155410256410256,
#    'buy_volume': 39.0,
#    'sell_avg_price': 0.0,
#    'sell_volume': 0.0,
#    'net_position': 39.0,
#    'realized_trade_pnl_pct': -1.0,
#    'realized_trade_pnl_quote': -0.0,
#    'unrealized_trade_pnl_pct': -0.0010953863185858305,
#    'unrealized_trade_pnl_quote': -0.04272006642484739,
#    'fees_quote': 0.001314,
#    'net_pnl_quote': -0.04403406642484739},
#   {'timestamp': 1748447832000,
#    'price': 1.3177,
#    'amount': 5.0,
#    'trade_type': 'SELL',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3155410256410256,
#    'buy_volume': 39.0,
#    'sell_avg_price': 1.3177,
#    'sell_volume': 5.0,
#    'net_position': 34.0,
#    'realized_trade_pnl_pct': 0.0016411303919028222,
#    'realized_trade_pnl_quote': 0.008205651959514112,
#    'unrealized_trade_pnl_pct': 0.0016411303919028222,
#    'unrealized_trade_pnl_quote': 0.05579843332469596,
#    'fees_quote': 0.001317,
#    'net_pnl_quote': 0.06268708528421008},
#   {'timestamp': 1748447907000,
#    'price': 1.3173,
#    'amount': 27.0,
#    'trade_type': 'SELL',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3155410256410256,
#    'buy_volume': 39.0,
#    'sell_avg_price': 1.3173625,
#    'sell_volume': 32.0,
#    'net_position': 7.0,
#    'realized_trade_pnl_pct': 0.001384581950294437,
#    'realized_trade_pnl_quote': 0.044306622409421986,
#    'unrealized_trade_pnl_pct': 0.001337072979626174,
#    'unrealized_trade_pnl_quote': 0.009359510857383218,
#    'fees_quote': 0.017783,
#    'net_pnl_quote': 0.03588313326680521},
#   {'timestamp': 1748447907000,
#    'price': 1.3173,
#    'amount': 5.0,
#    'trade_type': 'SELL',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3155410256410256,
#    'buy_volume': 39.0,
#    'sell_avg_price': 1.317354054054054,
#    'sell_volume': 37.0,
#    'net_position': 2.0,
#    'realized_trade_pnl_pct': 0.0013781618191230501,
#    'realized_trade_pnl_quote': 0.050991987307552854,
#    'unrealized_trade_pnl_pct': 0.001337072979626174,
#    'unrealized_trade_pnl_quote': 0.002674145959252348,
#    'fees_quote': 0.003293,
#    'net_pnl_quote': 0.0503731332668052},
#   {'timestamp': 1748447907000,
#    'price': 1.3173,
#    'amount': 2.0,
#    'trade_type': 'SELL',
#    'symbol': 'WLD-USDT',
#    'market': 'binance_perpetual',
#    'buy_avg_price': 1.3155410256410256,
#    'buy_volume': 39.0,
#    'sell_avg_price': 1.317351282051282,
#    'sell_volume': 39.0,
#    'net_position': 0.0,
#    'realized_trade_pnl_pct': 0.0013760546991488645,
#    'realized_trade_pnl_quote': 0.053666133266805714,
#    'unrealized_trade_pnl_pct': 0.0,
#    'unrealized_trade_pnl_quote': 0.0,
#    'fees_quote': 0.001317,
#    'net_pnl_quote': 0.052349133266805715}]}

# %%
await client.archived_bots.get_database_positions(dbs[1])
# Out:
# {'db_path': 'bots/archived/hummingbot-test_bot-2025.05.28_17.55/data/test_bot-2025.sqlite',
#  'positions': [],
#  'pagination': {'total': 0, 'limit': 100, 'offset': 0, 'has_more': False}}

# %%
await client.archived_bots.get_database_controllers(dbs[1]  )
# Out:
# {'db_path': 'bots/archived/hummingbot-test_bot-2025.05.28_17.55/data/test_bot-2025.sqlite',
#  'controllers': [{'id': 'binary-rich_0.1',
#    'controller_id': 1,
#    'timestamp': 1748447720.761528,
#    'type': 'generic',
#    'config': '{"controller_name": "grid_strike", "controller_type": "generic", "total_amount_quote": "200.0", "manual_kill_switch": false, "candles_config": [], "leverage": 20, "position_mode": "HEDGE", "connector_name": "binance_perpetual", "trading_pair": "WLD-USDT", "side": 1, "start_price": "1.3", "end_price": "1.47", "limit_price": "0.8644999999999999", "min_spread_between_orders": "0.0001", "min_order_amount_quote": "6.0", "max_open_orders": 3, "max_orders_per_batch": 1, "order_frequency": 2, "activation_bounds": "0.01", "keep_position": false, "triple_barrier_config": {"stop_loss": "0.1", "take_profit": "0.0001", "time_limit": null, "trailing_stop": null, "open_order_type": 3, "take_profit_order_type": 3, "stop_loss_order_type": 1, "time_limit_order_type": 1}}'}],
#  'total': 1}
