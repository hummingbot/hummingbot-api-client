# %%
from hummingbot_api_client import HummingbotAPIClient

client = HummingbotAPIClient(base_url='http://localhost:8000')
await client.init()

# %%
await client.portfolio.get_state()
# Out:
# {'master_account': {'binance': [{'token': 'BTC',
#     'units': 9.9e-06,
#     'price': 109368.52,
#     'value': 1.082748348,
#     'available_units': 9.9e-06},
#    {'token': 'ETH',
#     'units': 0.05609761,
#     'price': 2571.22,
#     'value': 144.23929678419998,
#     'available_units': 0.05609761},
#    {'token': 'USDT',
#     'units': 0.04213152,
#     'price': 1.0,
#     'value': 0.04213152,
#     'available_units': 0.04213152},
#    {'token': 'DOGE',
#     'units': 0.17112637,
#     'price': 0.1709,
#     'value': 0.029245496633,
#     'available_units': 0.17112637},
#    {'token': 'LDBNB',
#     'units': 0.19780126,
#     'price': 662.81,
#     'value': 131.1046531406,
#     'available_units': 0.19780126},
#    {'token': 'LDBTC',
#     'units': 5.92e-06,
#     'price': 109368.52,
#     'value': 0.6474616384,
#     'available_units': 5.92e-06},
#    {'token': 'LDETH',
#     'units': 0.49239796,
#     'price': 2571.22,
#     'value': 1266.0634827111999,
#     'available_units': 0.49239796},
#    {'token': 'SOL',
#     'units': 0.0001507,
#     'price': 151.91,
#     'value': 0.022892837,
#     'available_units': 0.0001507},
#    {'token': 'LDUSDC',
#     'units': 7.67584912,
#     'price': 1.0,
#     'value': 7.67584912,
#     'available_units': 7.67584912},
#    {'token': 'LDALGO',
#     'units': 12986.00210793,
#     'price': 0.1825,
#     'value': 2369.945384697225,
#     'available_units': 12986.00210793},
#    {'token': 'LDDOT',
#     'units': 1485.30354621,
#     'price': 3.578,
#     'value': 5314.41608833938,
#     'available_units': 1485.30354621},
#    {'token': 'LDCAKE',
#     'units': 0.0083856,
#     'price': 2.375,
#     'value': 0.0199158,
#     'available_units': 0.0083856},
#    {'token': 'LDSOL',
#     'units': 11.70737154,
#     'price': 151.91,
#     'value': 1778.4668106414,
#     'available_units': 11.70737154},
#    {'token': 'LDLUNC',
#     'units': 0.00557919,
#     'price': 5.786e-05,
#     'value': 3.2281193339999997e-07,
#     'available_units': 0.00557919},
#    {'token': 'LDPEPE',
#     'units': 5795413.63,
#     'price': 1.013e-05,
#     'value': 58.7075400719,
#     'available_units': 5795413.63},
#    {'token': 'FDUSD',
#     'units': 2.4083165,
#     'price': 1.0,
#     'value': 2.4083165,
#     'available_units': 2.4083165},
#    {'token': 'LDWLD',
#     'units': 25506.29242697,
#     'price': 0.954,
#     'value': 24333.00297532938,
#     'available_units': 25506.29242697},
#    {'token': 'LDFDUSD',
#     'units': 293.41303264,
#     'price': 1.0,
#     'value': 293.41303264,
#     'available_units': 293.41303264},
#    {'token': 'LDBONK',
#     'units': 29972138.68,
#     'price': 1.495e-05,
#     'value': 448.083473266,
#     'available_units': 29972138.68},
#    {'token': 'LDPIXEL',
#     'units': 9.53898955,
#     'price': 0.03543,
#     'value': 0.33796639975650006,
#     'available_units': 9.53898955},
#    {'token': 'LDWIF',
#     'units': 485.67421483,
#     'price': 0.885,
#     'value': 429.82168012455,
#     'available_units': 485.67421483},
#    {'token': 'LDLAYER',
#     'units': 0.06467718,
#     'price': 0.6564,
#     'value': 0.042454100952,
#     'available_units': 0.06467718},
#    {'token': 'LDRED',
#     'units': 0.33423511,
#     'price': 0.3101,
#     'value': 0.103646307611,
#     'available_units': 0.33423511},
#    {'token': 'LDGPS',
#     'units': 1.60877614,
#     'price': 0.02656,
#     'value': 0.0427290942784,
#     'available_units': 1.60877614},
#    {'token': 'LDBMT',
#     'units': 0.3570658,
#     'price': 0.1359,
#     'value': 0.04852524222,
#     'available_units': 0.3570658},
#    {'token': 'LDNIL',
#     'units': 0.2980829,
#     'price': 0.2982,
#     'value': 0.08888832078,
#     'available_units': 0.2980829},
#    {'token': 'LDPARTI',
#     'units': 0.34807342,
#     'price': 0.2126,
#     'value': 0.07400040909200001,
#     'available_units': 0.34807342},
#    {'token': 'LDGUN',
#     'units': 3.40499221,
#     'price': 0.02684,
#     'value': 0.0913899909164,
#     'available_units': 3.40499221},
#    {'token': 'LDBABY',
#     'units': 0.87037677,
#     'price': 0.05022,
#     'value': 0.0437103213894,
#     'available_units': 0.87037677},
#    {'token': 'LDWCT',
#     'units': 0.36356081,
#     'price': 0.3209,
#     'value': 0.116666663929,
#     'available_units': 0.36356081},
#    {'token': 'LDINIT',
#     'units': 0.27189551,
#     'price': 0.4565,
#     'value': 0.124120300315,
#     'available_units': 0.27189551},
#    {'token': 'LDHYPER',
#     'units': 0.23111509,
#     'price': 0.1082,
#     'value': 0.025006652738000002,
#     'available_units': 0.23111509},
#    {'token': 'LDSIGN',
#     'units': 2.30823498,
#     'price': 0.06827,
#     'value': 0.1575832020846,
#     'available_units': 2.30823498},
#    {'token': 'LDSTO',
#     'units': 0.1736809,
#     'price': 0.0726,
#     'value': 0.01260923334,
#     'available_units': 0.1736809},
#    {'token': 'LDSXT',
#     'units': 1.11423302,
#     'price': 0.0785,
#     'value': 0.08746729207,
#     'available_units': 1.11423302},
#    {'token': 'LDNXPC',
#     'units': 0.34065506,
#     'price': 0.9633,
#     'value': 0.328153019298,
#     'available_units': 0.34065506},
#    {'token': 'LDHAEDAL',
#     'units': 0.34666688,
#     'price': 0.1241,
#     'value': 0.043021359808,
#     'available_units': 0.34666688},
#    {'token': 'LDHUMA',
#     'units': 2.21243932,
#     'price': 0.03476,
#     'value': 0.07690439076319999,
#     'available_units': 2.21243932},
#    {'token': 'LDSOPH',
#     'units': 27228.31981882,
#     'price': 0.03341,
#     'value': 909.6981651467762,
#     'available_units': 27228.31981882},
#    {'token': 'LDRESOLV',
#     'units': 0.22696681,
#     'price': 0.1425,
#     'value': 0.032342770425,
#     'available_units': 0.22696681},
#    {'token': 'LDHOME',
#     'units': 2.27812989,
#     'price': 0.02035,
#     'value': 0.0463599432615,
#     'available_units': 2.27812989},
#    {'token': 'LDSPK',
#     'units': 2.29390454,
#     'price': 0.036264,
#     'value': 0.08318615423855999,
#     'available_units': 2.29390454},
#    {'token': 'LDNEWT',
#     'units': 0.14360174,
#     'price': 0.343,
#     'value': 0.049255396820000005,
#     'available_units': 0.14360174},
#    {'token': 'LDSAHARA',
#     'units': 1.43513501,
#     'price': 0.07943,
#     'value': 0.1139927738443,
#     'available_units': 1.43513501}]}}
